# %%
#instalando o pacote
pip install pacoteprocessamentoimagem
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#importando as funções do pacote
from pacoteprocessamentoimagem import combinacao, transformacao, io, plot

# %%
#testando as funções do pacote
imagem1 = io.ler_imagem('https://github.com/isabela-rossetti/pacote_imagem_python/blob/main/imagem2.jpg?raw=True')
imagem2 = io.ler_imagem('https://github.com/isabela-rossetti/pacote_imagem_python/blob/main/imagem1.jpg?raw=True')

# %%
#testando as funções do pacote
plot.plot_imagem(imagem1)
plot.plot_imagem(imagem2)

# %%
#testando as funções do pacote
combinacao_imagem = combinacao.transferindo_histograma_dupla(imagem1, imagem2)
plot.plot_imagem(combinacao_imagem)
